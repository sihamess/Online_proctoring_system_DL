# %% [markdown]
# #**Cheating detection in in online exam usins OP data: data2**

# %% [markdown]
# # 1. Install and Import Dependencies

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
from IPython.display import Image  # for displaying images
import os
import random
import shutil
from sklearn.model_selection import train_test_split
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt
import uuid   # Unique identifier
import os
import time

random.seed(108)

# %% [markdown]
# # 2. Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-1-8 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# # 3. load and unyip data

# %%
#!unzip "/content/drive/MyDrive/data2_yolov5/data2.zip" -d "/content/drive/MyDrive/data2_yolov5"

# %%
cd /content/drive/MyDrive/paper 3 siham/data2_notebooks/2.yolov5
# Out:
# /content/drive/MyDrive/paper 3 siham/data2_notebooks/2.yolov5

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # 4. Train from scratch

# %%
temps_debut = time.time()
# !python train.py --img 640 --batch 16 --epochs 70 --data "/content/drive/MyDrive/paper 3 siham/data2_notebooks/2.yolov5/dataset_v2 .yaml" --weights "/content/drive/MyDrive/paper 3 siham/data2_notebooks/2.yolov5/yolov5s.pt" --cache

temps_fin = time.time()
temps_execution = temps_fin - temps_debut
print(f"Le temps d'exécution est de {temps_execution} secondes.")
# Out:
# 2024-01-08 23:08:46.485823: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-08 23:08:46.485885: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-08 23:08:46.487193: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # 5. Inference

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/paper 3 siham/data2_notebooks/2.yolov5/runs/train/exp12/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2024-1-9 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
t1=time.time()
# !python detect.py --source "/content/drive/MyDrive/paper 3 siham/data/data2_yolov5/images/test" --weights "/content/drive/MyDrive/paper 3 siham/data2_notebooks/2.yolov5/runs/train/exp12/weights/best.pt" --conf 0.25 --name test_prediction

t2= time.time()
temps_execution = t2 - t1
print(f"Le temps d'exécution est de {temps_execution} secondes.")
# Out:
# detect: weights=['/content/drive/MyDrive/paper 3 siham/data2_notebooks/2.yolov5/runs/train/exp12/weights/best.pt'], source=/content/drive/MyDrive/paper 3 siham/data/data2_yolov5/images/test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=test_prediction, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2024-1-5 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/2019 /content/drive/MyDrive/paper 3 siham/data/data2_yolov5/images/test/1002.jpg: 480x640 1 no_cheating, 81.6ms
# ...

# %%
import glob
from IPython.display import Image, display
i=0
for imageName in glob.glob ('/content/drive/MyDrive/paper 3 siham/data2_notebooks/2.yolov5/runs/detect/test_prediction/*.jpg'):
  i+=1
  if i<2019:
    display(Image(filename=imageName))
    print('\n')

# %% [markdown]
# #Computing the mAP on the test dataset

# %%
t3=time.time()
# !python val.py --weights  "/content/drive/MyDrive/paper 3 siham/data2_notebooks/2.yolov5/runs/train/exp12/weights/best.pt" --data "/content/drive/MyDrive/paper 3 siham/data2_notebooks/2.yolov5/dataset_v2 .yaml" --task test
t4 = time.time()
temps_execution =t4 - t3
print(f"Le temps d'exécution est de {temps_execution} secondes.")
# Out:
# val: data=/content/drive/MyDrive/paper 3 siham/data2_notebooks/2.yolov5/dataset_v2 .yaml, weights=['/content/drive/MyDrive/paper 3 siham/data2_notebooks/2.yolov5/runs/train/exp12/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 2024-1-5 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/drive/MyDrive/paper 3 siham/data/data2_yolov5/labels/test... 2019 images, 0 backgrounds, 0 corrupt: 100% 2019/2019 [02:15<00:00, 14.90it/s]
# test: New cache created: /content/drive/MyDrive/paper 3 siham/data/data2_yolov5/labels/test.cache
# ...
